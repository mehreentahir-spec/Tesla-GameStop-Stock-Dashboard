# %%
from IPython.display import display, HTML
from pathlib import Path
import webbrowser
import random
from datetime import date, timedelta

# =========================================================
# DEMO DATA
# =========================================================

random.seed(7)

n = 260
dates = [
    (date.today() - timedelta(days=n-i)).isoformat()
    for i in range(n)
]

price = []
v = 155

for i in range(n):
    v += random.uniform(-4.5, 4.8) + (0.025 if i > 70 else 0)
    price.append(round(max(100, v), 2))

revenue = [24.32, 25.17, 23.35, 25.17, 21.30]
quarters = ["Q1 2024", "Q2 2024", "Q3 2024", "Q4 2024", "Q1 2025"]

# JavaScript data
dates_js = str(dates).replace("'", '"')
price_js = str(price)
quarters_js = str(quarters).replace("'", '"')
revenue_js = str(revenue)

# =========================================================
# COMPLETE DASHBOARD
# =========================================================

html = r"""
<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">

<title>Market Insights Dashboard</title>

<link rel="preconnect" href="https://fonts.googleapis.com">
<link href="https://fonts.googleapis.com/css2?family=Inter:wght@400;500;600;700;800&family=Space+Grotesk:wght@600;700&display=swap" rel="stylesheet">

<script src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>

<style>

* {
    box-sizing: border-box;
}

body {
    margin: 0;
    background: #030a16;
    color: #eef5ff;
    font-family: Inter, Arial, sans-serif;
}

.wrap {
    min-height: 100vh;
    padding: 18px;
    background:
        radial-gradient(circle at 82% 0%, #24204e 0, transparent 32%),
        linear-gradient(135deg, #061425, #030a16 65%);
}

.dashboard {
    display: grid;
    grid-template-columns: 245px 1fr;
    gap: 15px;
    max-width: 1500px;
    margin: auto;
}

/* SIDEBAR */

.sidebar {
    background: linear-gradient(180deg, #071225, #040a15);
    border: 1px solid #17243b;
    border-radius: 22px;
    padding: 20px 16px;
    min-height: 960px;
}

.brand {
    display: flex;
    gap: 12px;
    align-items: center;
    margin: 4px 10px 35px;
}

.logo {
    font-size: 42px;
    filter: drop-shadow(0 0 10px #19cfff);
}

.brand h2 {
    font: 700 24px 'Space Grotesk';
    line-height: 1;
    margin: 0;
}

.brand h2 span {
    color: #8959ff;
}

.brand small {
    display: block;
    color: #dbe5f5;
    font-size: 10px;
    margin-top: 8px;
    white-space: nowrap;
}

.nav {
    padding: 14px 15px;
    margin: 9px 0;
    border-radius: 10px;
    color: #d7dfed;
    font-size: 15px;
    cursor: pointer;
    transition: .3s;
}

.nav:hover {
    background: #182544;
    transform: translateX(4px);
}

.nav.active {
    background: linear-gradient(90deg, #5142ee, #6250e8);
    box-shadow: 0 0 22px #5142ee66;
}

.ad {
    margin-top: 270px;
    border: 1px solid #944fff;
    border-radius: 17px;
    padding: 20px 18px;
    height: 325px;
    background:
        radial-gradient(circle at 50% 100%, #401b8c88, transparent 48%),
        #10122e;
}

.ad h3 {
    font-size: 17px;
    margin: 25px 0 10px;
}

.ad b {
    color: #35f29b;
    font-size: 18px;
}

.ad p {
    line-height: 1.8;
}

.car {
    font-size: 62px;
    text-align: center;
    margin-top: 35px;
    filter: drop-shadow(0 0 15px #a442ff);
}

/* MAIN */

.main {
    min-width: 0;
}

.hero {
    min-height: 108px;
    border: 1px solid #1b2b45;
    border-radius: 18px;
    padding: 20px 26px;
    display: flex;
    justify-content: space-between;
    align-items: center;
    background: linear-gradient(110deg, #10223b, #0b172b);
}

.hero h1 {
    font: 700 25px 'Space Grotesk';
    margin: 0 0 8px;
}

.hero p {
    margin: 0;
    color: #c4cede;
    font-size: 14px;
}

.select-title {
    font-size: 11px;
    color: #aebbd0;
    margin-bottom: 8px;
}

.company {
    display: flex;
    gap: 18px;
}

.company button {
    height: 61px;
    width: 230px;
    border-radius: 12px;
    border: 1px solid #202e49;
    background: #091426;
    color: white;
    font-weight: 700;
    font-size: 15px;
    cursor: pointer;
    transition: .3s;
}

.company button:hover {
    transform: translateY(-3px);
}

.company button.active {
    background: linear-gradient(110deg, #ed173e, #c70c2c);
    border-color: #ff4765;
    box-shadow: 0 0 18px #e9153d55;
}

/* FILTERS */

.controls {
    display: grid;
    grid-template-columns: repeat(4, 1fr);
    gap: 16px;
    margin: 20px 0;
}

label {
    display: block;
    color: #8192ab;
    font-size: 11px;
    margin-bottom: 7px;
}

select {
    width: 100%;
    background: #0a182b;
    border: 1px solid #233650;
    color: #b8c4d6;
    padding: 12px;
    border-radius: 10px;
}

/* CARDS */

.cards {
    display: grid;
    grid-template-columns: repeat(4, 1fr);
    gap: 14px;
}

.card {
    height: 160px;
    border-radius: 15px;
    padding: 20px;
    background: #09182a;
    border: 1px solid #273650;
    position: relative;
    overflow: hidden;
    transition: .35s;
}

.card:hover {
    transform: translateY(-6px);
    box-shadow: 0 12px 30px #00000055;
}

.card:after {
    content: "";
    position: absolute;
    inset: auto 0 0;
    height: 3px;
    background: var(--c);
}

.card.red {
    --c: #ff3b58;
    border-color: #ff3b58;
    box-shadow: 0 0 18px #ff3b5830;
}

.card.green {
    --c: #20df86;
    border-color: #20df86;
    box-shadow: 0 0 18px #20df8630;
}

.card.purple {
    --c: #934cff;
    border-color: #934cff;
    box-shadow: 0 0 18px #934cff30;
}

.card.blue {
    --c: #19aaff;
    border-color: #19aaff;
    box-shadow: 0 0 18px #19aaff30;
}

.card .label {
    font-size: 12px;
    color: #d6deea;
}

.value {
    font: 700 29px 'Space Grotesk';
    margin: 14px 0 7px;
}

.note {
    font-size: 12px;
    color: #a8b4c6;
}

.bigicon {
    position: absolute;
    right: 20px;
    top: 26px;
    font-size: 42px;
    opacity: .75;
}

/* CHARTS */

.grid {
    display: grid;
    grid-template-columns: 1.55fr 1fr;
    gap: 14px;
    margin-top: 14px;
}

.panel {
    background: #071426;
    border: 1px solid #1b2c45;
    border-radius: 15px;
    padding: 17px;
    min-width: 0;
}

.panel h3 {
    font: 600 16px 'Space Grotesk';
    margin: 0 0 13px;
}

.chart {
    height: 335px;
}

/* LOWER PANELS */

.lower {
    display: grid;
    grid-template-columns: 1.4fr 1fr;
    gap: 14px;
    margin-top: 14px;
}

.stats {
    display: grid;
    grid-template-columns: repeat(5, 1fr);
    gap: 0;
}

.stat {
    padding: 10px 12px;
    border-right: 1px solid #26364e;
}

.stat:last-child {
    border: 0;
}

.stat small {
    color: #b4bfd0;
    font-size: 11px;
}

.stat strong {
    display: block;
    font-size: 21px;
    margin-top: 16px;
}

.cyan {
    color: #16bfff;
}

.pink {
    color: #ff3c63;
}

.violet {
    color: #a96bff;
}

.green {
    color: #29e990;
}

.gold {
    color: #ffc857;
}

.summary {
    display: grid;
    grid-template-columns: repeat(4, 1fr);
    text-align: center;
    gap: 8px;
}

.circle {
    font-size: 30px;
    margin: 8px auto;
    border: 2px solid;
    border-radius: 50%;
    width: 60px;
    height: 60px;
    padding-top: 12px;
}

.summary small {
    color: #b9c4d4;
}

.summary strong {
    display: block;
    margin-top: 7px;
    font-size: 16px;
}

.footer {
    margin-top: 14px;
    border: 1px solid #27355b;
    background: #111b3a;
    border-radius: 12px;
    padding: 13px 20px;
    color: #b6c1d2;
    font-size: 12px;
    display: flex;
    justify-content: space-between;
}

/* RESPONSIVE */

@media(max-width:1000px) {

    .dashboard {
        grid-template-columns: 1fr;
    }

    .sidebar {
        display: none;
    }

    .cards,
    .controls {
        grid-template-columns: repeat(2, 1fr);
    }

    .grid,
    .lower {
        grid-template-columns: 1fr;
    }

    .hero {
        flex-direction: column;
        align-items: flex-start;
        gap: 20px;
    }

}

</style>
</head>

<body>

<div class="wrap">

<div class="dashboard">

<!-- SIDEBAR -->

<aside class="sidebar">

    <div class="brand">
        <div class="logo">🚘</div>

        <div>
            <h2>
                MARKET<br>
                <span>INSIGHTS</span>
            </h2>

            <small>Stock & Revenue Dashboard</small>
        </div>
    </div>

    <div class="nav active">⌂　Overview</div>
    <div class="nav">⌁　Stock Price</div>
    <div class="nav">＄　Revenue</div>
    <div class="nav">▥　Statistics</div>
    <div class="nav">ⓘ　About</div>

    <div class="ad">
        <h3>DRIVE YOUR</h3>
        <b>INVESTMENTS</b>

        <p>
            Data. Insights.<br>
            Better Decisions.
        </p>

        <div class="car">🏎️</div>
    </div>

</aside>


<!-- MAIN -->

<main class="main">

<section class="hero">

    <div>
        <h1>Welcome back! 👋</h1>

        <p>
            Track performance, analyze trends and make
            smarter investment decisions.
        </p>
    </div>

    <div>

        <div class="select-title">
            SELECT COMPANY
        </div>

        <div class="company">

            <button class="active"
                    onclick="choose('Tesla', this)">
                🚘　TESLA
            </button>

            <button onclick="choose('GameStop', this)">
                🎮　GAMESTOP
            </button>

        </div>

    </div>

</section>


<!-- FILTERS -->

<div class="controls">

    <div>
        <label>Company</label>

        <select id="company" onchange="changeCompany(this.value)">
            <option>Tesla</option>
            <option>GameStop</option>
        </select>
    </div>

    <div>
        <label>Time range</label>

        <select>
            <option>1Y</option>
            <option>3Y</option>
            <option>5Y</option>
            <option>10Y</option>
            <option>Max</option>
        </select>
    </div>

    <div>
        <label>Price chart</label>

        <select>
            <option>Neon line</option>
            <option>Area glow</option>
            <option>Candlestick</option>
        </select>
    </div>

    <div>
        <label>Revenue chart</label>

        <select>
            <option>Gradient bars</option>
            <option>Line + markers</option>
        </select>
    </div>

</div>


<!-- KPI CARDS -->

<div class="cards">

    <div class="card red">

        <div class="label">
            LATEST CLOSE PRICE
        </div>

        <div class="value" id="close">
            $179.57
        </div>

        <div class="note">
            As of today
        </div>

        <div class="bigicon">🚘</div>

    </div>


    <div class="card green">

        <div class="label">
            TOTAL REVENUE (TTM)
        </div>

        <div class="value">
            $97.69B
        </div>

        <div class="note">
            Trailing Twelve Months
        </div>

        <div class="bigicon">💰</div>

    </div>


    <div class="card purple">

        <div class="label">
            52 WEEK HIGH
        </div>

        <div class="value">
            $488.54
        </div>

        <div class="note">
            Highest in selected period
        </div>

        <div class="bigicon">🚀</div>

    </div>


    <div class="card blue">

        <div class="label">
            52 WEEK LOW
        </div>

        <div class="value">
            $167.41
        </div>

        <div class="note">
            Lowest in selected period
        </div>

        <div class="bigicon">🛡️</div>

    </div>

</div>


<!-- CHARTS -->

<div class="grid">

    <section class="panel">

        <h3>📈 STOCK PRICE HISTORY</h3>

        <div id="priceChart" class="chart"></div>

    </section>


    <section class="panel">

        <h3>💰 QUARTERLY REVENUE</h3>

        <div id="revChart" class="chart"></div>

    </section>

</div>


<!-- LOWER PANELS -->

<div class="lower">

    <section class="panel">

        <h3>📊 KEY STATISTICS</h3>

        <div class="stats">

            <div class="stat">
                <small>Average Close Price</small>
                <strong class="cyan">$303.36</strong>
            </div>

            <div class="stat">
                <small>Price Change (1Y)</small>
                <strong class="pink">-17.48%</strong>
            </div>

            <div class="stat">
                <small>Daily Volatility (Std)</small>
                <strong class="violet">3.17%</strong>
            </div>

            <div class="stat">
                <small>Best Day</small>
                <strong class="green">16.23% ↑</strong>
            </div>

            <div class="stat">
                <small>Worst Day</small>
                <strong class="pink">-15.43% ↓</strong>
            </div>

        </div>

    </section>


    <section class="panel">

        <h3>📈 TRADING SUMMARY</h3>

        <div class="summary">

            <div>
                <div class="circle violet">▥</div>
                <small>Avg. Volume</small>
                <strong>106.55M</strong>
            </div>

            <div>
                <div class="circle cyan">$</div>
                <small>Market Cap</small>
                <strong>579.38B</strong>
            </div>

            <div>
                <div class="circle green">↗</div>
                <small>P/E Ratio</small>
                <strong>144.84</strong>
            </div>

            <div>
                <div class="circle gold">◷</div>
                <small>Dividend Yield</small>
                <strong>0.00%</strong>
            </div>

        </div>

    </section>

</div>


<div class="footer">

    <span>
        ⓘ　Data provided by Yahoo Finance &
        IBM Investor Relations. Delayed by 15 minutes.
    </span>

    <span>
        Last Updated: Today　🟢
    </span>

</div>

</main>

</div>
</div>


<script>

/* DATA */

const x = __DATES__;
const y = __PRICES__;
const q = __QUARTERS__;
const r = __REVENUE__;


/* CHART BASE STYLE */

const layoutBase = {

    paper_bgcolor: 'rgba(0,0,0,0)',

    plot_bgcolor: 'rgba(0,0,0,0)',

    font: {
        color: '#b4c1d4',
        family: 'Inter'
    },

    margin: {
        l: 45,
        r: 15,
        t: 10,
        b: 35
    },

    xaxis: {
        showgrid: false,
        zeroline: false
    },

    yaxis: {
        gridcolor: 'rgba(255,255,255,.08)',
        zeroline: false
    },

    hovermode: 'x unified'

};


/* STOCK PRICE CHART */

Plotly.newPlot(

    'priceChart',

    [{

        x: x,

        y: y,

        type: 'scatter',

        mode: 'lines',

        line: {
            color: '#ff3658',
            width: 2.5
        },

        fill: 'tozeroy',

        fillcolor: 'rgba(255,45,75,.12)',

        hovertemplate:
            '%{x}<br>Close: $%{y:.2f}<extra></extra>'

    }],

    {

        ...layoutBase,

        yaxis: {
            ...layoutBase.yaxis,
            tickprefix: '$'
        }

    },

    {
        displayModeBar: false,
        responsive: true
    }

);


/* REVENUE CHART */

Plotly.newPlot(

    'revChart',

    [{

        x: q,

        y: r,

        type: 'bar',

        marker: {
            color: '#ff3153'
        },

        text: r.map(v => v.toFixed(2) + 'B'),

        textposition: 'outside',

        hovertemplate:
            '%{x}<br>Revenue: $%{y:.2f}B<extra></extra>'

    }],

    {

        ...layoutBase,

        yaxis: {
            ...layoutBase.yaxis,
            ticksuffix: 'B'
        }

    },

    {
        displayModeBar: false,
        responsive: true
    }

);


/* COMPANY BUTTONS */

function choose(name, btn) {

    document.querySelectorAll('.company button')
        .forEach(b => b.classList.remove('active'));

    btn.classList.add('active');

    document.getElementById('company').value = name;

    changeCompany(name);

}


function changeCompany(name) {

    document.querySelectorAll('.company button')
        .forEach(b => {

            b.classList.toggle(
                'active',
                b.innerText.includes(name.toUpperCase())
            );

        });

    document.getElementById('close').innerText =
        name === 'Tesla' ? '$179.57' : '$24.18';

}

</script>

</body>
</html>
"""

# =========================================================
# INSERT DATA
# =========================================================

html = html.replace("__DATES__", dates_js)
html = html.replace("__PRICES__", price_js)
html = html.replace("__QUARTERS__", quarters_js)
html = html.replace("__REVENUE__", revenue_js)

# =========================================================
# SAVE AND OPEN IN BROWSER
# =========================================================

dashboard_file = Path.cwd() / "market_insights_dashboard.html"

dashboard_file.write_text(
    html,
    encoding="utf-8"
)

webbrowser.open(
    dashboard_file.resolve().as_uri()
)

print("✅ Dashboard browser mein open ho gaya!")
print("📁 Saved file:", dashboard_file)
# Out:
# ✅ Dashboard browser mein open ho gaya!
# 📁 Saved file: C:\Users\Nasar\Documents\DATAANALYSIS\market_insights_dashboard.html
